# %%
import re
import string
from collections import Counter
import numpy as np

# %%
def read_file(filename):
  with open(filename, "r") as file:
    lines = file.readlines()
    words = []
    for line in lines:
      words += re.findall(r'\w+', line.lower())

  return words

# %%
words = read_file("/content/big.csv")
print(f"There are {len(words)} total words in the file")
# Out:
# There are 83101 total words in the file

# %%
vocabs = set(words)
print(f"There are {len(vocabs)} unique words in the vocabulary")
# Out:
# There are 14235 unique words in the vocabulary

# %%
word_counts = Counter(words)
a=input("enter a word you want to count in this file: ")
print(word_counts[a])
# Out:
# enter a word you want to count in this file: this
# 24

# %%
total_word_count = float(sum(word_counts.values()))
word_probas = {word: word_counts[word] / total_word_count for word in word_counts.keys()}

# %%
print(word_probas["this"])
# Out:
# 0.00028880518886656

# %%
def split(word):
  return [(word[:i], word[i:]) for i in range(len(word) + 1)]

# %%
a1=input("enter a word :")
print(split(a1))
# Out:
# enter a word :thsi
# [('', 'thsi'), ('t', 'hsi'), ('th', 'si'), ('ths', 'i'), ('thsi', '')]

# %%
def delete(word):
  return [l + r[1:] for l,r in split(word)if r]

# %%
print(delete(a1))
# Out:
# ['hsi', 'tsi', 'thi', 'ths']

# %%
def swap(word):
  return [l + r[1] + r[0] + r[2:] for l, r in split(word) if len(r)>1]

# %%
print(swap(a1))
# Out:
# ['htsi', 'tshi', 'this']

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
def replace(word):
  letters = string.ascii_lowercase
  return [l + c + r[1:] for l, r in split(word) if r for c in letters]

# %%
print(replace(a1))
# Out:
# ['ahsi', 'bhsi', 'chsi', 'dhsi', 'ehsi', 'fhsi', 'ghsi', 'hhsi', 'ihsi', 'jhsi', 'khsi', 'lhsi', 'mhsi', 'nhsi', 'ohsi', 'phsi', 'qhsi', 'rhsi', 'shsi', 'thsi', 'uhsi', 'vhsi', 'whsi', 'xhsi', 'yhsi', 'zhsi', 'tasi', 'tbsi', 'tcsi', 'tdsi', 'tesi', 'tfsi', 'tgsi', 'thsi', 'tisi', 'tjsi', 'tksi', 'tlsi', 'tmsi', 'tnsi', 'tosi', 'tpsi', 'tqsi', 'trsi', 'tssi', 'ttsi', 'tusi', 'tvsi', 'twsi', 'txsi', 'tysi', 'tzsi', 'thai', 'thbi', 'thci', 'thdi', 'thei', 'thfi', 'thgi', 'thhi', 'thii', 'thji', 'thki', 'thli', 'thmi', 'thni', 'thoi', 'thpi', 'thqi', 'thri', 'thsi', 'thti', 'thui', 'thvi', 'thwi', 'thxi', 'thyi', 'thzi', 'thsa', 'thsb', 'thsc', 'thsd', 'thse', 'thsf', 'thsg', 'thsh', 'thsi', 'thsj', 'thsk', 'thsl', 'thsm', 'thsn', 'thso', 'thsp', 'thsq', 'thsr', 'thss', 'thst', 'thsu', 'thsv', 'thsw', 'thsx', 'thsy', 'thsz']

# %%
def insert(word):
  letters = string.ascii_lowercase
  return [l + c + r for l, r in split(word) for c in letters]

# %%
print(insert(a1))
# Out:
', 'trdsi', 'uhsgi', 'thhsir', 'tfhsdi', 'lthusi', 'tcji', 'tmsiq', 'kthpsi', 'kthsii', 'tlsip', 'tqhsis', 'thjiq', 'tbhsai', 'tvtsi', 'thsiet', 'tehqi', 'thksli', 'lthsk', 'bhsg', 'ztmsi', 'wthsg', 'uzhsi', 'fthsgi', 'zthski', 'jhsn', 'ymsi', 'thgie', 'thrb', 'tkhsgi', 'ktkhsi', 'tfsk', 'ythrsi', 'tzei', 'thyy', 'hfhsi', 'tnhshi', 'chhi', 'tysni', 'xithsi', 'tvhesi', 'bhsr', 'qxhsi', 'othsb', 'zhsiz', 'rhqi', 'stghsi', 'dthsb', 'wusi', 'tisq', 'tnhtsi', 'cthsiq', 'tnhsk', 'thsnw', 'wthsqi', 'thoiv', 'mzsi', 'othni', 'nhsix', 'thbki', 'lhci', 'thdbsi', 'tphsji', 'thsbdi', 'thsij', 'shsif', 'gthsj', 'tdhsq', 'thvsia', 'thsgid', 'tbhsui', 'mtcsi', 'yesi', 'tmhsgi', 'othoi', 'ulhsi', 'tnsb', 'thxsio', 'thush', 'cthsik', 'tnihsi', 'tehsc', 'thsiau', 'tnsu', 'tchsr', 'wdhsi', 'tthsoi', 'bthrsi', 'thswin', 'shsti', 'ohsmi', 'lythsi', 'tmghsi', 'thuai', 'thnai', 'thash', 'uthdsi', 'thmui', 'tphmsi', 'yhsig', 'tmsvi', 'tfmsi', 'tihvsi', 'muhsi', 'thsoa', 'thiusi', 'thisqi', 'uesi', 'ltchsi', 'thswli', 'tzhsig', 'thmrsi', 'ethsq', 'athci', 'cthsqi', 'ohnsi', 'twshsi', 'whsq', 'thyxi', 'zthsig', 'gqthsi', 'lthqsi', 'gfhsi', 'hhsd', 'lhwsi', 'tsehsi', 'nthsai', 'nthsk', 'thdit', 'tcsic', 'thsqii', 'tpghsi', 'thyik', 'tihasi', 'tbhst', 'thksih', 'thmsiw', 'thsou', 'vthsim', 'tpsm', 'rmthsi', 'thsiov', 'ythzi', 'thsict', 'twhsxi', 'jthyi', 'blsi', 'qthsy', 'kghsi', 'kthqi', 'tnhsic', 'etnhsi', 'itrsi', 'thshyi', 'tshsi', 'ltqsi', 'ythi ...

# %%
def correct_spelling(word, vocabulary, word_probabilities):
  if word in vocabulary:
    print(f"{word} is already correctly spelt")
    return

  suggestions = edit1(word) or edit2(word) or [word]
  best_guesses = [w for w in suggestions if w in vocabulary]
  return [(w, word_probabilities[w]) for w in best_guesses]

# %%
word = input("enter a word :")
corrections = correct_spelling(word, vocabs, word_probas)

if corrections:
  print(corrections)
  probs = np.array([c[1] for c in corrections])
  best = np.argmax(probs)
  correct = corrections[best][0]
  print(f"{correct} is suggested for {word}")
# Out:
# enter a word :botes
# [('notes', 7.220129721664e-05), ('bones', 2.4067099072213332e-05), ('bote', 1.2033549536106666e-05), ('boxes', 1.2033549536106666e-05), ('votes', 1.2033549536106666e-05)]
# notes is suggested for botes
